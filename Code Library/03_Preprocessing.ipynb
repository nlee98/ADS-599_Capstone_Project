# %% [markdown]
# # Notebook 3: Preprocessing
#
# _For USD-599 Capstone Project by Hunter Blum, Kyle Esteban Dalope, and Nicholas Lee (Summer 2023)_
#
# ***
#
# **Content Overview:**
# 1. Missing Value Handling

# %%
# Library Imports
import pandas as pd
import numpy as np

# %% [markdown]
# ## Missing Value Handling

# %%
# Read in the csv file from the previous notebook
preproc_df = pd.read_csv("../Data/clean_df.csv.gz",
                         compression = "gzip")

preproc_df.head(1)
# Out:
#    host_listings_count property_type        room_type  bathrooms  bedrooms
# 0                 52.0   Entire home  Entire home/apt        2.0       2.0  \
#
#    price  minimum_nights  maximum_nights  minimum_minimum_nights
# 0  728.0               2              28                     1.0  \
#
#    maximum_maximum_nights  ... calculated_host_listings_count
# 0                  1125.0  ...                             30  \
#
#    calculated_host_listings_count_private_rooms
# 0                                             0  \
#
#    calculated_host_listings_count_shared_rooms reviews_per_month  zipcode
# 0                                            0              3.77    92109  \
#
#    median_income_dollars  property_type_binary  private  sentiment
# 0                95170.0                 house        1   0.900577  \
#
#    review_score_weighted
# 0                 150.04
#
# [1 rows x 24 columns]

# %%
preproc_df.isna().sum()
# Out:
# host_listings_count                               51
# property_type                                      0
# room_type                                          0
# bathrooms                                          6
# bedrooms                                        1538
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             2
# maximum_maximum_nights                             2
# has_availability                                   0
# availability_30                                    0
# availability_365                                   0
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3186
# zipcode                                            0
# median_income_dollars                              0
# property_type_binary                               0
# private                                            0
# sentiment                                          0
# review_score_weighted                           3186
# dtype: int64

# %%
# Assess the types of listings missing records bedrooms
preproc_df[preproc_df["bedrooms"].isnull()]["property_type"].value_counts()
# Out:
# property_type
# Entire rental unit             645
# Entire guesthouse              190
# Entire condo                   174
# Entire guest suite             136
# Entire serviced apartment      102
# Entire home                     72
# Entire loft                     44
# Camper/RV                       23
# Entire cottage                  19
# Private room in rental unit     18
# Entire bungalow                 17
# Tiny home                       15
# Private room in home            12
# Room in boutique hotel          11
# Private room in resort          10
# Entire vacation home             9
# Room in hotel                    8
# Private room in guest suite      6
# Private room in guesthouse       4
# Private room in condo            3
# Private room in camper/rv        3
# Private room in hostel           2
# Entire place                     2
# Barn                             2
# Private room in bungalow         1
# Private room in cottage          1
# Private room in loft             1
# Casa particular                  1
# Entire villa                     1
# Entire townhouse                 1
# Campsite                         1
# Tent                             1
# Earthen home                     1
# Entire cabin                     1
# Tipi                             1
# Name: count, dtype: int64

# %% [markdown]
# It can be reasonably assumed that property type values with "room" or "RV" are a have a single bedroom. So the missing values can be filled with the value of 1.

# %%
preproc_df[preproc_df["property_type"].astype(str).str.contains(r"rental unit")].sort_values("bedrooms", ascending = False)
# Out:
#        host_listings_count       property_type        room_type  bathrooms
# 4465                  88.0  Entire rental unit  Entire home/apt        7.0  \
# 99                   659.0  Entire rental unit  Entire home/apt        8.0
# 3454                 659.0  Entire rental unit  Entire home/apt        5.0
# 1551                  63.0  Entire rental unit  Entire home/apt        8.0
# 3509                  72.0  Entire rental unit  Entire home/apt        5.0
# ...                    ...                 ...              ...        ...
# 17271                  1.0  Entire rental unit  Entire home/apt        1.0
# 17429                  3.0  Entire rental unit  Entire home/apt        1.0
# 17562                 43.0  Entire rental unit  Entire home/apt        1.0
# 17736                  3.0  Entire rental unit  Entire home/apt        1.0
# 17778                  2.0  Entire rental unit  Entire home/apt        1.0
#
#        bedrooms   price  minimum_nights  maximum_nights
# 4465       11.0  1595.0               2              28  \
# 99          9.0   972.0               1             365
# 3454        9.0  1165.0               1             365
# 1551        9.0   849.0               1             365
# 3509        9.0   977.0               1             365
# ...         ...     ...             ...             ...
# 17271       NaN    39.0               1            1125
# 17429       NaN   110.0               4             180
# 17562       NaN   133.0               7             150
# 17736       NaN   140.0               4            1125
# 17778       NaN   103.0               2              29
#
#        minimum_minimum_nights  maximum_maximum_nights  ...
# 4465                      2.0                    28.0  ...  \
# 99                        2.0                   365.0  ...
# 3454                      2.0                   365.0  ...
# 1551                      2.0                   365.0  ...
# 3509                      2.0                   365.0  ...
# ...                       ...                     ...  ...
# 17271                     1.0                  1125.0  ...
# 17429                     4.0                   180.0  ...
# 17562                     7.0                  1125.0  ...
# 17736                     4.0                  1125.0  ...
# 17778                     2.0                    29.0  ...
#
#       calculated_host_listings_count
# 4465                              72  \
# 99                                32
# 3454                              32
# 1551                              58
# 3509                              66
# ...                              ...
# 17271                              1
# 17429                              3
# 17562                             36
# 17736                              3
# 17778                              1
#
#        calculated_host_listings_count_private_rooms
# 4465                                              0  \
# 99                                                0
# 3454                                              0
# 1551                                              0
# 3509                                              0
# ...                                             ...
# 17271                                             0
# 17429                                             0
# 17562                                             0
# 17736                                             0
# 17778                                             0
#
#        calculated_host_listings_count_shared_rooms reviews_per_month  zipcode
# 4465                                             0               NaN    92103  \
# 99                                               0              0.25    92109
# 3454                                             0              0.56    92103
# 1551                                             0              0.14    92109
# 3509                                             0              0.54    92103
# ...                                            ...               ...      ...
# 17271                                            0              2.94    92173
# 17429                                            0              0.12    91942
# 17562                                            0              1.63    92075
# 17736                                            0              1.85    92075
# 17778                                            0              4.88    92075
#
#        median_income_dollars  property_type_binary  private  sentiment
# 4465                 84756.0                 house        1   0.998420  \
# 99                   95170.0                 house        1   0.998444
# 3454                 84756.0                 house        1   0.999799
# 1551                 95170.0                 house        1   0.989029
# 3509                 84756.0                 house        1   0.999802
# ...                      ...                   ...      ...        ...
# 17271                54003.0                 house        1   0.019995
# 17429                72145.0                 house        1   0.999057
# 17562               111500.0                 house        1   0.999643
# 17736               111500.0                 house        1   0.999657
# 17778               111500.0                 house        1   0.999701
#
#        review_score_weighted
# 4465                     NaN
# 99                     14.01
# 3454                   85.00
# 1551                   14.01
# 3509                   90.00
# ...                      ...
# 17271                 236.18
# 17429                  10.00
# 17562                 224.10
# 17736                 654.36
# 17778                 298.22
#
# [4265 rows x 24 columns]

# %%
# Fill bedrooms with a value of 1 for those that are listed as rooms
# Indexes of records with the word "room" or RV in the property_type
room_idx = preproc_df[
    preproc_df["property_type"].astype(str).str.contains("|".join(["room", "Room", "RV"]))
    ].index.tolist()

preproc_df.loc[room_idx, "bedrooms"] = preproc_df.loc[room_idx, "bedrooms"].fillna(1)

# %%
# Look at all unique bedroom-bathroom combinations in the dataset
bed_bath_df = preproc_df.groupby(["bathrooms", "bedrooms"]).size().reset_index().rename(columns={0:"count"})

# Look at listings that have one bathroom, to assess the most common number of bedrooms
bed_bath_df[bed_bath_df["bathrooms"] == 1]
# Out:
#     bathrooms  bedrooms  count
# 5         1.0       1.0   8932
# 6         1.0       2.0   2314
# 7         1.0       3.0    356
# 8         1.0       4.0     14
# 9         1.0       5.0      3
# 10        1.0       6.0      1
# 11        1.0       7.0      1
# 12        1.0       9.0      1
# 13        1.0      11.0      1
# 14        1.0      12.0      3
# 15        1.0      17.0      1

# %%
# Look at all listings with 0 bathrooms
bed_bath_df[bed_bath_df["bathrooms"] == 0]
# Out:
#    bathrooms  bedrooms  count
# 0        0.0       1.0     47
# 1        0.0       2.0      5
# 2        0.0       3.0      1
# 3        0.0       9.0      1

# %% [markdown]
# Based on the above, if a listing has zero or one bathroom, it most likely also only has one bedroom. Therefore, if a listing has zero or one bathroom, the value for bedroom will be filled with 1.

# %%
# Fill bedrooms with a value of 1 for 1 bathroom
# Indexes of records with 1 bathrooms
bathroom_1_idx = preproc_df.loc[
    preproc_df["bathrooms"].isin([0,1])
    ].index.tolist()

preproc_df.loc[bathroom_1_idx, "bedrooms"] = preproc_df.loc[bathroom_1_idx, "bedrooms"].fillna(1)
# This fills all but 10 missing bedroom values

# %%
preproc_df[preproc_df["bedrooms"].isnull()]
# Out:
#        host_listings_count property_type        room_type  bathrooms
# 11666                  0.0   Entire home  Entire home/apt        2.0  \
# 11667                  0.0   Entire home  Entire home/apt        2.0
# 13799                 29.0   Entire home  Entire home/apt        6.0
# 14509                  7.0     Tiny home  Entire home/apt        2.0
# 16290                191.0   Entire home  Entire home/apt        2.0
#
#        bedrooms   price  minimum_nights  maximum_nights
# 11666       NaN   499.0               2             999  \
# 11667       NaN   499.0               2             365
# 13799       NaN  1175.0               2              21
# 14509       NaN    99.0               1            1125
# 16290       NaN   151.0              30            1125
#
#        minimum_minimum_nights  maximum_maximum_nights  ...
# 11666                     2.0                  1125.0  ...  \
# 11667                     2.0                  1125.0  ...
# 13799                     2.0                    21.0  ...
# 14509                     1.0                  1125.0  ...
# 16290                    30.0                  1125.0  ...
#
#       calculated_host_listings_count
# 11666                             15  \
# 11667                             15
# 13799                             26
# 14509                              7
# 16290                              9
#
#        calculated_host_listings_count_private_rooms
# 11666                                             4  \
# 11667                                             4
# 13799                                             0
# 14509                                             5
# 16290                                             0
#
#        calculated_host_listings_count_shared_rooms reviews_per_month  zipcode
# 11666                                            0               NaN    92126  \
# 11667                                            0              0.20    92126
# 13799                                            0               NaN    92104
# 14509                                            0              5.39    92122
# 16290                                            0              0.85    91910
#
#        median_income_dollars  property_type_binary  private  sentiment
# 11666               105284.0                 house        1   0.999438  \
# 11667               105284.0                 house        1   0.999400
# 13799                79929.0                 house        1   0.994432
# 14509                88073.0                 house        0   0.573923
# 16290                77005.0                 house        1   0.999634
#
#        review_score_weighted
# 11666                    NaN
# 11667                   8.00
# 13799                    NaN
# 14509                 528.64
# 16290                 136.01
#
# [5 rows x 24 columns]

# %%
bed_bath_df[bed_bath_df["bathrooms"] == 2]
# Out:
#     bathrooms  bedrooms  count
# 16        2.0       1.0    249
# 17        2.0       2.0   2331
# 18        2.0       3.0   1696
# 19        2.0       4.0    497
# 20        2.0       5.0     48
# 21        2.0       6.0      4
# 22        2.0       8.0      1
# 23        2.0      20.0      1
# 24        2.0      34.0      1

# %% [markdown]
# Do we think the 20 and 34 bedrooms are errors? Should we fix those?

# %%
# The last five were filled by manually looking up the homes using the url provided in the original data
preproc_df.loc[11666, "bedrooms"] = 1 # She's charing $5,000 a night!!!
preproc_df.loc[11667, "bedrooms"] = 2 
preproc_df.loc[13799, "bedrooms"] = 2
preproc_df.loc[14509, "bedrooms"] = 2 # A tiny home logically cannot have more than 2 bedrooms
preproc_df.loc[16290, "bedrooms"] = 2 # Most 2 bathroom places have 2 bedrooms in the data

# %%
# Remaining number of missing 
preproc_df.isnull().sum()
# Out:
# host_listings_count                               51
# property_type                                      0
# room_type                                          0
# bathrooms                                          6
# bedrooms                                           0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             2
# maximum_maximum_nights                             2
# has_availability                                   0
# availability_30                                    0
# availability_365                                   0
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3186
# zipcode                                            0
# median_income_dollars                              0
# property_type_binary                               0
# private                                            0
# sentiment                                          0
# review_score_weighted                           3186
# dtype: int64

# %%
preproc_df[preproc_df["bedrooms"].isnull()]
# Out:
#        host_listings_count       property_type        room_type  bathrooms
# 4                      4.0           Camper/RV  Entire home/apt        NaN  \
# 32                    44.0  Entire rental unit  Entire home/apt        1.0
# 35                     0.0           Camper/RV  Entire home/apt        0.0
# 36                     0.0           Camper/RV  Entire home/apt        0.0
# 53                     2.0        Entire condo  Entire home/apt        1.0
# ...                    ...                 ...              ...        ...
# 18486                  1.0   Entire guesthouse  Entire home/apt        1.0
# 18501                  1.0           Tiny home  Entire home/apt        1.0
# 18508                  1.0  Entire guest suite  Entire home/apt        1.0
# 18519                  1.0  Entire guest suite  Entire home/apt        1.0
# 18625                  1.0   Entire guesthouse  Entire home/apt        1.0
#
#        bedrooms  price  minimum_nights  maximum_nights
# 4           NaN   62.0               1            1125  \
# 32          NaN  139.0               1            1125
# 35          NaN  189.0               2             365
# 36          NaN  179.0               2             365
# 53          NaN  270.0               1              30
# ...         ...    ...             ...             ...
# 18486       NaN  157.0               2              45
# 18501       NaN   65.0               2            1125
# 18508       NaN   75.0               2              40
# 18519       NaN   78.0               2            1125
# 18625       NaN  160.0               2            1125
#
#        minimum_minimum_nights  maximum_maximum_nights  ...
# 4                         1.0                  1125.0  ...  \
# 32                        1.0                  1125.0  ...
# 35                        2.0                   365.0  ...
# 36                        2.0                   365.0  ...
# 53                        1.0                  1125.0  ...
# ...                       ...                     ...  ...
# 18486                     2.0                    45.0  ...
# 18501                     2.0                  1125.0  ...
# 18508                     2.0                    40.0  ...
# 18519                     2.0                  1125.0  ...
# 18625                     2.0                  1125.0  ...
#
#       calculated_host_listings_count
# 4                                  3  \
# 32                                40
# 35                                 3
# 36                                 3
# 53                                 2
# ...                              ...
# 18486                              1
# 18501                              1
# 18508                              1
# 18519                              1
# 18625                              1
#
#        calculated_host_listings_count_private_rooms
# 4                                                 1  \
# 32                                                0
# 35                                                0
# 36                                                0
# 53                                                0
# ...                                             ...
# 18486                                             0
# 18501                                             0
# 18508                                             0
# 18519                                             0
# 18625                                             0
#
#        calculated_host_listings_count_shared_rooms reviews_per_month  zipcode
# 4                                                0              0.12    92109  \
# 32                                               0              1.30    92109
# 35                                               0              0.10    92109
# 36                                               0               NaN    92109
# 53                                               0              2.33    92109
# ...                                            ...               ...      ...
# 18486                                            0               NaN    92114
# 18501                                            0               NaN    92114
# 18508                                            0              1.88    92114
# 18519                                            0              2.42    92114
# 18625                                            0              3.56    92020
#
#        median_income_dollars  property_type_binary  private  sentiment
# 4                    95170.0                 house        0   0.062897  \
# 32                   95170.0                 house        1   0.987491
# 35                   95170.0                 house        0   0.998417
# 36                   95170.0                 house        0   0.998387
# 53                   95170.0                 house        1   0.975706
# ...                      ...                   ...      ...        ...
# 18486                79917.0                 house        1   0.979519
# 18501                79917.0                 house        0   0.991848
# 18508                79917.0                 house        1   0.997124
# 18519                79917.0                 house        1   0.005117
# 18625                64691.0                 house        1   0.998942
#
#        review_score_weighted
# 4                       5.00
# 32                     69.00
# 35                      2.00
# 36                       NaN
# 53                     30.03
# ...                      ...
# 18486                    NaN
# 18501                    NaN
# 18508                 283.86
# 18519                 511.98
# 18625                  35.00
#
# [1477 rows x 24 columns]
